# %%
import numpy as mp

# %%
import pandas as pd 
import missingno as msno

# %%
pwd
# Out:
# 'E:\\CODE\\Machine Learning\\Agour course'

# %%
path = r'data\01- Data Analysis\02- Numpy & pandas\Files\homelessness.csv'

# %%
df_homelessness = pd.read_csv(path)

# %%
df_homelessness.shape
# Out:
# (51, 5)

# %%
df_homelessness.head(5)
# Out:
#                region       state  individuals  family_members  state_pop
# 0  East South Central     Alabama         2570             864    4887681
# 1             Pacific      Alaska         1434             582     735139
# 2            Mountain     Arizona         7259            2606    7158024
# 3  West South Central    Arkansas         2280             432    3009733
# 4             Pacific  California       109008           20964   39461588

# %%
df_homelessness.describe()
# Out:
#          individuals  family_members     state_pop
# count      51.000000       51.000000  5.100000e+01
# mean     7225.784314     3504.882353  6.405637e+06
# std     15991.025083     7805.411811  7.327258e+06
# min       434.000000       75.000000  5.776010e+05
# 25%      1446.500000      592.000000  1.777414e+06
# 50%      3082.000000     1482.000000  4.461153e+06
# 75%      6781.500000     3196.000000  7.340946e+06
# max    109008.000000    52070.000000  3.946159e+07

# %%
df_homelessness.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   region          51 non-null     object
#  1   state           51 non-null     object
#  2   individuals     51 non-null     int64
#  3   family_members  51 non-null     int64
#  4   state_pop       51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
df_homelessness.isna()
# Out:
#     region  state  individuals  family_members  state_pop
# 0    False  False        False           False      False
# 1    False  False        False           False      False
# 2    False  False        False           False      False
# 3    False  False        False           False      False
# 4    False  False        False           False      False
# 5    False  False        False           False      False
# 6    False  False        False           False      False
# 7    False  False        False           False      False
# 8    False  False        False           False      False
# 9    False  False        False           False      False
# 10   False  False        False           False      False
# 11   False  False        False           False      False
# 12   False  False        False           False      False
# 13   False  False        False           False      False
# 14   False  False        False           False      False
# ...

# %%
df_homelessness.isna().any().sum()
# Out:
# 0

# %%
msno.matrix(df_homelessness)
# Out:
# <AxesSubplot:>

# %%
msno.bar(df_homelessness)
# Out:
# <AxesSubplot:>

# %%
df_homelessness.columns
# Out:
# Index(['region', 'state', 'individuals', 'family_members', 'state_pop'], dtype='object')

# %%
df_homelessness.values
# Out:
# array([['East South Central', 'Alabama', 2570, 864, 4887681],
#        ['Pacific', 'Alaska', 1434, 582, 735139],
#        ['Mountain', 'Arizona', 7259, 2606, 7158024],
#        ['West South Central', 'Arkansas', 2280, 432, 3009733],
#        ['Pacific', 'California', 109008, 20964, 39461588],
#        ['Mountain', 'Colorado', 7607, 3250, 5691287],
#        ['New England', 'Connecticut', 2280, 1696, 3571520],
#        ['South Atlantic', 'Delaware', 708, 374, 965479],
#        ['South Atlantic', 'District of Columbia', 3770, 3134, 701547],
#        ['South Atlantic', 'Florida', 21443, 9587, 21244317],
#        ['South Atlantic', 'Georgia', 6943, 2556, 10511131],
#        ['Pacific', 'Hawaii', 4131, 2399, 1420593],
#        ['Mountain', 'Idaho', 1297, 715, 1750536],
#        ['East North Central', 'Illinois', 6752, 3891, 12723071],
#        ['East North Central', 'Indiana', 3776, 1482, 6695497],
#        ['West North Central', 'Iowa', 1711, 1038, 3148618],
# ...

# %%
df_homelessness.region
# Out:
# 0     East South Central
# 1                Pacific
# 2               Mountain
# 3     West South Central
# 4                Pacific
# 5               Mountain
# 6            New England
# 7         South Atlantic
# 8         South Atlantic
# 9         South Atlantic
# 10        South Atlantic
# 11               Pacific
# 12              Mountain
# 13    East North Central
# 14    East North Central
# 15    West North Central
# 16    West North Central
# 17    East South Central
# 18    West South Central
# 19           New England
# 20        South Atlantic
# 21           New England
# 22    East North Central
# 23    West North Central
# 24    East South Central
# 25    West North Central
# 26              Mountain
# 27    West North Central
# 28              Mountain
# 29           New England
# 30          Mid-Atlantic
# 31              Mountain
# 32          Mid-Atlantic
# 33        South Atlantic
# 34    West North Central
# 35    East North Central
# 36    West South Central
# ...

# %%
df_homelessness['individuals']
# Out:
# 0       2570
# 1       1434
# 2       7259
# 3       2280
# 4     109008
# 5       7607
# 6       2280
# 7        708
# 8       3770
# 9      21443
# 10      6943
# 11      4131
# 12      1297
# 13      6752
# 14      3776
# 15      1711
# 16      1443
# 17      2735
# 18      2540
# 19      1450
# 20      4914
# 21      6811
# 22      5209
# 23      3993
# 24      1024
# 25      3776
# 26       983
# 27      1745
# 28      7058
# 29       835
# 30      6048
# 31      1949
# 32     39827
# 33      6451
# 34       467
# 35      6929
# 36      2823
# 37     11139
# 38      8163
# 39       747
# 40      3082
# 41       836
# 42      6139
# 43     19199
# 44      1904
# 45       780
# 46      3928
# 47     16424
# 48      1021
# 49      2740
# 50       434
# Name: individuals, dtype: int64

# %%
df_homelessness[['individuals', 'region']]
# Out:
#     individuals              region
# 0          2570  East South Central
# 1          1434             Pacific
# 2          7259            Mountain
# 3          2280  West South Central
# 4        109008             Pacific
# 5          7607            Mountain
# 6          2280         New England
# 7           708      South Atlantic
# 8          3770      South Atlantic
# 9         21443      South Atlantic
# 10         6943      South Atlantic
# 11         4131             Pacific
# 12         1297            Mountain
# 13         6752  East North Central
# 14         3776  East North Central
# 15         1711  West North Central
# 16         1443  West North Central
# 17         2735  East South Central
# 18         2540  West South Central
# 19         1450         New England
# 20         4914      South Atlantic
# 21         6811         New England
# 22         5209  East North Central
# 23         3993  West North Central
# 24         1024  East South Central
# ...

# %%
df_homelessness.sort_values(by = 'individuals' )
# Out:
#                 region                 state  individuals  family_members  \
# 50            Mountain               Wyoming          434             205
# 34  West North Central          North Dakota          467              75
# 7       South Atlantic              Delaware          708             374
# 39         New England          Rhode Island          747             354
# 45         New England               Vermont          780             511
# 29         New England         New Hampshire          835             615
# 41  West North Central          South Dakota          836             323
# 26            Mountain               Montana          983             422
# 48      South Atlantic         West Virginia         1021             222
# 24  East South Central           Mississippi         1024             328
# 12            Mountain                 Idaho         1297             715
# 1              Pacific                Alaska         1434             582
# ...

# %%
df_homelessness.sort_values(by = 'individuals' ,ascending = False )
# Out:
#                 region                 state  individuals  family_members  \
# 4              Pacific            California       109008           20964
# 32        Mid-Atlantic              New York        39827           52070
# 9       South Atlantic               Florida        21443            9587
# 43  West South Central                 Texas        19199            6111
# 47             Pacific            Washington        16424            5880
# 37             Pacific                Oregon        11139            3337
# 38        Mid-Atlantic          Pennsylvania         8163            5349
# 5             Mountain              Colorado         7607            3250
# 2             Mountain               Arizona         7259            2606
# 28            Mountain                Nevada         7058             486
# 10      South Atlantic               Georgia         6943            2556
# 35  East North Central                  Ohio         6929            3320
# ...

# %%
## df_homelessness.sort_values(by = 'individuals' , ascending=False ,inplace=True)
## =
## df_new = df_homelessness.sort_values(by = 'individuals' , ascending=False)

# %%
df_homelessness.sort_values(by = ['individuals' , 'family_members'] ,axis= 0 )
# ترتيب بمتغيرين الاولوية للاول
# Out:
#                 region                 state  individuals  family_members  \
# 50            Mountain               Wyoming          434             205
# 34  West North Central          North Dakota          467              75
# 7       South Atlantic              Delaware          708             374
# 39         New England          Rhode Island          747             354
# 45         New England               Vermont          780             511
# 29         New England         New Hampshire          835             615
# 41  West North Central          South Dakota          836             323
# 26            Mountain               Montana          983             422
# 48      South Atlantic         West Virginia         1021             222
# 24  East South Central           Mississippi         1024             328
# 12            Mountain                 Idaho         1297             715
# 1              Pacific                Alaska         1434             582
# ...

# %%
df_homelessness.sort_values(by = ['individuals' , 'family_members'] ,axis= 0 ,ascending=['True','False'])
# Out:
#                 region                 state  individuals  family_members  \
# 50            Mountain               Wyoming          434             205
# 34  West North Central          North Dakota          467              75
# 7       South Atlantic              Delaware          708             374
# 39         New England          Rhode Island          747             354
# 45         New England               Vermont          780             511
# 29         New England         New Hampshire          835             615
# 41  West North Central          South Dakota          836             323
# 26            Mountain               Montana          983             422
# 48      South Atlantic         West Virginia         1021             222
# 24  East South Central           Mississippi         1024             328
# 12            Mountain                 Idaho         1297             715
# 1              Pacific                Alaska         1434             582
# ...

# %%
df_homelessness['region'].unique()
## ال values المميزة داخل كل صف
# Out:
# array(['East South Central', 'Pacific', 'Mountain', 'West South Central',
#        'New England', 'South Atlantic', 'East North Central',
#        'West North Central', 'Mid-Atlantic'], dtype=object)

# %%
df_homelessness['region'].value_counts()
# Out:
# South Atlantic        9
# Mountain              8
# West North Central    7
# New England           6
# Pacific               5
# East North Central    5
# East South Central    4
# West South Central    4
# Mid-Atlantic          3
# Name: region, dtype: int64

# %%
df_homelessness['region'] == 'Mountain'
# Out:
# 0     False
# 1     False
# 2      True
# 3     False
# 4     False
# 5      True
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26     True
# 27    False
# 28     True
# 29    False
# 30    False
# 31     True
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44     True
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50     True
# Name: region, dtype: bool

# %%
df_homelessness[df_homelessness['region'] == 'Mountain']
# Out:
#       region       state  individuals  family_members  state_pop
# 2   Mountain     Arizona         7259            2606    7158024
# 5   Mountain    Colorado         7607            3250    5691287
# 12  Mountain       Idaho         1297             715    1750536
# 26  Mountain     Montana          983             422    1060665
# 28  Mountain      Nevada         7058             486    3027341
# 31  Mountain  New Mexico         1949             602    2092741
# 44  Mountain        Utah         1904             972    3153550
# 50  Mountain     Wyoming          434             205     577601

# %%
df_homelessness[df_homelessness['family_members'] > 300]
# Out:
#                 region                 state  individuals  family_members  \
# 0   East South Central               Alabama         2570             864
# 1              Pacific                Alaska         1434             582
# 2             Mountain               Arizona         7259            2606
# 3   West South Central              Arkansas         2280             432
# 4              Pacific            California       109008           20964
# 5             Mountain              Colorado         7607            3250
# 6          New England           Connecticut         2280            1696
# 7       South Atlantic              Delaware          708             374
# 8       South Atlantic  District of Columbia         3770            3134
# 9       South Atlantic               Florida        21443            9587
# 10      South Atlantic               Georgia         6943            2556
# 11             Pacific                Hawaii         4131            2399
# ...

# %%
df_homelessness[(df_homelessness['family_members'] > 300) & (df_homelessness['family_members'] < 600 )]
# Out:
#                 region         state  individuals  family_members  state_pop
# 1              Pacific        Alaska         1434             582     735139
# 3   West South Central      Arkansas         2280             432    3009733
# 7       South Atlantic      Delaware          708             374     965479
# 18  West South Central     Louisiana         2540             519    4659690
# 24  East South Central   Mississippi         1024             328    2981020
# 26            Mountain       Montana          983             422    1060665
# 28            Mountain        Nevada         7058             486    3027341
# 39         New England  Rhode Island          747             354    1058287
# 41  West North Central  South Dakota          836             323     878698
# 45         New England       Vermont          780             511     624358

# %%
df_homelessness[df_homelessness['region'] == 'Pacific']['state_pop'].mean()
# Out:
# 10664615.0

# %%
df_homelessness.groupby('region')['state_pop'].mean()
# Out:
# region
# East North Central    9.377277e+06
# East South Central    4.775371e+06
# Mid-Atlantic          1.373910e+07
# Mountain              3.063968e+06
# New England           2.471554e+06
# Pacific               1.066462e+07
# South Atlantic        7.247736e+06
# West North Central    3.050034e+06
# West South Central    1.005958e+07
# Name: state_pop, dtype: float64

# %%
df_homelessness.groupby('region')['state_pop'].count()
# Out:
# region
# East North Central    5
# East South Central    4
# Mid-Atlantic          3
# Mountain              8
# New England           6
# Pacific               5
# South Atlantic        9
# West North Central    7
# West South Central    4
# Name: state_pop, dtype: int64

# %%
df_homelessness['region'].value_counts()
# Out:
# South Atlantic        9
# Mountain              8
# West North Central    7
# New England           6
# Pacific               5
# East North Central    5
# East South Central    4
# West South Central    4
# Mid-Atlantic          3
# Name: region, dtype: int64

# %%
df_homelessness.head()
# Out:
#                region       state  individuals  family_members  state_pop
# 0  East South Central     Alabama         2570             864    4887681
# 1             Pacific      Alaska         1434             582     735139
# 2            Mountain     Arizona         7259            2606    7158024
# 3  West South Central    Arkansas         2280             432    3009733
# 4             Pacific  California       109008           20964   39461588

# %%
df_homelessness.groupby('region')['state_pop'].agg({'mean','std','max','min','var'})
# Out:
#                          max          mean           std      min  \
# region
# East North Central  12723071  9.377277e+06  3.032497e+06  5807406
# East South Central   6771631  4.775371e+06  1.561633e+06  2981020
# Mid-Atlantic        19530351  1.373910e+07  5.383823e+06  8886025
# Mountain             7158024  3.063968e+06  2.284641e+06   577601
# New England          6882635  2.471554e+06  2.392057e+06   624358
# Pacific             39461588  1.066462e+07  1.631872e+07   735139
# South Atlantic      21244317  7.247736e+06  6.481193e+06   701547
# West North Central   6121623  3.050034e+06  2.130333e+06   758080
# West South Central  28628666  1.005958e+07  1.239780e+07  3009733
#
#                              var
# region
# East North Central  9.196039e+12
# East South Central  2.438699e+12
# Mid-Atlantic        2.898555e+13
# Mountain            5.219585e+12
# New England         5.721938e+12
# Pacific             2.663005e+14
# South Atlantic      4.200586e+13
# ...

# %%
df_homelessness['my_new_column']= df_homelessness['state_pop']/df_homelessness['individuals']

# %%
df_homelessness
# Out:
#                 region                 state  individuals  family_members  \
# 0   East South Central               Alabama         2570             864
# 1              Pacific                Alaska         1434             582
# 2             Mountain               Arizona         7259            2606
# 3   West South Central              Arkansas         2280             432
# 4              Pacific            California       109008           20964
# 5             Mountain              Colorado         7607            3250
# 6          New England           Connecticut         2280            1696
# 7       South Atlantic              Delaware          708             374
# 8       South Atlantic  District of Columbia         3770            3134
# 9       South Atlantic               Florida        21443            9587
# 10      South Atlantic               Georgia         6943            2556
# 11             Pacific                Hawaii         4131            2399
# ...

# %%
df_homelessness['state_pop'].mean()
# Out:
# 6405637.274509804

# %%
df_homelessness['state_pop'].median()
# Out:
# 4461153.0

# %%
df_homelessness['state_pop'].quantile(0.5)
# Out:
# 4461153.0

# %%
df_homelessness['state_pop'].quantile([.5,0.25,0.75])
# Out:
# 0.50    4461153.0
# 0.25    1777413.5
# 0.75    7340946.5
# Name: state_pop, dtype: float64

# %%
df_homelessness.groupby(['region' ,'state'])['state_pop'].mean()
# Out:
# region              state
# East North Central  Illinois                12723071.0
#                     Indiana                  6695497.0
#                     Michigan                 9984072.0
#                     Ohio                    11676341.0
#                     Wisconsin                5807406.0
# East South Central  Alabama                  4887681.0
#                     Kentucky                 4461153.0
#                     Mississippi              2981020.0
#                     Tennessee                6771631.0
# Mid-Atlantic        New Jersey               8886025.0
#                     New York                19530351.0
#                     Pennsylvania            12800922.0
# Mountain            Arizona                  7158024.0
#                     Colorado                 5691287.0
#                     Idaho                    1750536.0
#                     Montana                  1060665.0
#                     Nevada                   3027341.0
# ...

# %%
df_homelessness.groupby(['region' ,'state'])['state_pop'].agg({'min','max'})
# Out:
#                                               min       max
# region             state
# East North Central Illinois              12723071  12723071
#                    Indiana                6695497   6695497
#                    Michigan               9984072   9984072
#                    Ohio                  11676341  11676341
#                    Wisconsin              5807406   5807406
# East South Central Alabama                4887681   4887681
#                    Kentucky               4461153   4461153
#                    Mississippi            2981020   2981020
#                    Tennessee              6771631   6771631
# Mid-Atlantic       New Jersey             8886025   8886025
#                    New York              19530351  19530351
#                    Pennsylvania          12800922  12800922
# Mountain           Arizona                7158024   7158024
#                    Colorado               5691287   5691287
# ...
